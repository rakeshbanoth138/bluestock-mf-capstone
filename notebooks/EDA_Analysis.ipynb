# %%
import pandas as pd
from pathlib import Path
raw_path = Path("../data/raw")
files = ["01_fund_master.csv", "02_nav_history.csv", "07_scheme_performance.csv", "08_investor_transactions.csv"]
#now for every 
for file in files: 
    print(file)
    df = pd.read_csv(raw_path/file)
    print("\nColumns:")
    print(df.columns.tolist())
    print("\nShape:")
    print(df.shape)
    print("\nFirst 5 rows:")
    print(df.head())
# Out:
# 01_fund_master.csv
#
# Columns:
# ['amfi_code', 'fund_house', 'scheme_name', 'category', 'sub_category', 'plan', 'launch_date', 'benchmark', 'expense_ratio_pct', 'exit_load_pct', 'min_sip_amount', 'min_lumpsum_amount', 'fund_manager', 'risk_category', 'sebi_category_code']
#
# Shape:
# (40, 15)
#
# First 5 rows:
#    amfi_code       fund_house                                   scheme_name  \
# 0     119551  SBI Mutual Fund     SBI Bluechip Fund - Regular Plan - Growth
# 1     119552  SBI Mutual Fund      SBI Bluechip Fund - Direct Plan - Growth
# 2     119598  SBI Mutual Fund    SBI Small Cap Fund - Regular Plan - Growth
# 3     119599  SBI Mutual Fund     SBI Small Cap Fund - Direct Plan - Growth
# 4     119120  SBI Mutual Fund  SBI Magnum Gilt Fund - Regular Plan - Growth
#
#   category sub_category     plan launch_date                  benchmark  \
# 0   Equity    Large Cap  Regular  2006-02-14              NIFTY 100 TRI
# ...

# %%
df = pd.read_csv("../data/raw/01_fund_master.csv")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   amfi_code           40 non-null     int64
#  1   fund_house          40 non-null     object
#  2   scheme_name         40 non-null     object
#  3   category            40 non-null     object
#  4   sub_category        40 non-null     object
#  5   plan                40 non-null     object
#  6   launch_date         40 non-null     object
#  7   benchmark           40 non-null     object
#  8   expense_ratio_pct   40 non-null     float64
#  9   exit_load_pct       40 non-null     float64
#  10  min_sip_amount      40 non-null     int64
#  11  min_lumpsum_amount  40 non-null     int64
#  12  fund_manager        40 non-null     object
#  13  risk_category       40 non-null     object
#  14  sebi_category_code  40 non-null     object
# dtypes: float64(2), int64(3), object(10)
# ...

# %%
df = pd.read_csv("../data/raw/01_fund_master.csv")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   amfi_code           40 non-null     int64
#  1   fund_house          40 non-null     object
#  2   scheme_name         40 non-null     object
#  3   category            40 non-null     object
#  4   sub_category        40 non-null     object
#  5   plan                40 non-null     object
#  6   launch_date         40 non-null     object
#  7   benchmark           40 non-null     object
#  8   expense_ratio_pct   40 non-null     float64
#  9   exit_load_pct       40 non-null     float64
#  10  min_sip_amount      40 non-null     int64
#  11  min_lumpsum_amount  40 non-null     int64
#  12  fund_manager        40 non-null     object
#  13  risk_category       40 non-null     object
#  14  sebi_category_code  40 non-null     object
# dtypes: float64(2), int64(3), object(10)
# ...

# %%
df = pd.read_csv("../data/raw/07_scheme_performance.csv")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   amfi_code           40 non-null     int64
#  1   scheme_name         40 non-null     object
#  2   fund_house          40 non-null     object
#  3   category            40 non-null     object
#  4   plan                40 non-null     object
#  5   return_1yr_pct      40 non-null     float64
#  6   return_3yr_pct      40 non-null     float64
#  7   return_5yr_pct      40 non-null     float64
#  8   benchmark_3yr_pct   40 non-null     float64
#  9   alpha               40 non-null     float64
#  10  beta                40 non-null     float64
#  11  sharpe_ratio        40 non-null     float64
#  12  sortino_ratio       40 non-null     float64
#  13  std_dev_ann_pct     40 non-null     float64
#  14  max_drawdown_pct    40 non-null     float64
# ...

# %%
df = pd.read_csv("../data/raw/08_investor_transactions.csv")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32778 entries, 0 to 32777
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   investor_id         32778 non-null  object
#  1   transaction_date    32778 non-null  object
#  2   amfi_code           32778 non-null  int64
#  3   transaction_type    32778 non-null  object
#  4   amount_inr          32778 non-null  int64
#  5   state               32778 non-null  object
#  6   city                32778 non-null  object
#  7   city_tier           32778 non-null  object
#  8   age_group           32778 non-null  object
#  9   gender              32778 non-null  object
#  10  annual_income_lakh  32778 non-null  float64
#  11  payment_mode        32778 non-null  object
#  12  kyc_status          32778 non-null  object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 3.3+ MB
# None

# %%
df["transaction_type"].value_counts()
# Out:
# transaction_type
# SIP           19716
# Lumpsum        8095
# Redemption     4967
# Name: count, dtype: int64

# %%
df["kyc_status"].value_counts()
# Out:
# kyc_status
# Verified    30146
# Pending      2632
# Name: count, dtype: int64

# %%
(df["amount_inr"] <= 0).sum()
# Out:
# np.int64(0)

# %%
df["transaction_date"] = pd.to_datetime(df["transaction_date"])
print(df["transaction_date"].dtype)
# Out:
# datetime64[ns]

# %%
df.to_csv("../data/processed/08_investor_transactions_cleaned.csv", index=False)

# %%
import pandas as pd
df = pd.read_csv("../data/raw/02_nav_history.csv")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46000 entries, 0 to 45999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   amfi_code  46000 non-null  int64
#  1   date       46000 non-null  object
#  2   nav        46000 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.1+ MB
# None

# %%
df = pd.read_csv("../data/raw/02_nav_history.csv")
print(df.date)
# Out:
# 0        2022-01-03
# 1        2022-01-04
# 2        2022-01-05
# 3        2022-01-06
# 4        2022-01-07
#             ...
# 45995    2026-05-25
# 45996    2026-05-26
# 45997    2026-05-27
# 45998    2026-05-28
# 45999    2026-05-29
# Name: date, Length: 46000, dtype: object

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 46000 entries, 0 to 45999
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   amfi_code  46000 non-null  int64
#  1   date       46000 non-null  datetime64[ns]
#  2   nav        46000 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 1.1 MB
# None

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
(df["nav"] <= 0).sum()
# Out:
# np.int64(0)

# %%
df = df.sort_values(by = ["amfi_code", "date"])

# %%
df.head(10)
# Out:
#       amfi_code       date       nav
# 5750     100016 2022-01-03  520.4608
# 5751     100016 2022-01-04  515.0971
# 5752     100016 2022-01-05  521.7239
# 5753     100016 2022-01-06  515.7880
# 5754     100016 2022-01-07  515.1639
# 5755     100016 2022-01-10  510.7136
# 5756     100016 2022-01-11  513.5542
# 5757     100016 2022-01-12  512.3195
# 5758     100016 2022-01-13  510.2445
# 5759     100016 2022-01-14  514.3636

# %%
df["nav"].isnull().sum()
# Out:
# np.int64(0)

# %%
df.to_csv("../data/processed/02_nav_history_cleaned.csv",index=False)

# %%
df = pd.read_csv("../data/raw/07_scheme_performance.csv")
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   amfi_code           40 non-null     int64
#  1   scheme_name         40 non-null     object
#  2   fund_house          40 non-null     object
#  3   category            40 non-null     object
#  4   plan                40 non-null     object
#  5   return_1yr_pct      40 non-null     float64
#  6   return_3yr_pct      40 non-null     float64
#  7   return_5yr_pct      40 non-null     float64
#  8   benchmark_3yr_pct   40 non-null     float64
#  9   alpha               40 non-null     float64
#  10  beta                40 non-null     float64
#  11  sharpe_ratio        40 non-null     float64
#  12  sortino_ratio       40 non-null     float64
#  13  std_dev_ann_pct     40 non-null     float64
#  14  max_drawdown_pct    40 non-null     float64
# ...

# %%
df = pd.read_csv("../data/raw/07_scheme_performance.csv")

# %%
print(df.columns.tolist())
# Out:
# ['amfi_code', 'scheme_name', 'fund_house', 'category', 'plan', 'return_1yr_pct', 'return_3yr_pct', 'return_5yr_pct', 'benchmark_3yr_pct', 'alpha', 'beta', 'sharpe_ratio', 'sortino_ratio', 'std_dev_ann_pct', 'max_drawdown_pct', 'aum_crore', 'expense_ratio_pct', 'morningstar_rating', 'risk_grade']

# %%
df[["return_1yr_pct","return_3yr_pct","return_5yr_pct"]].describe()
# Out:
#        return_1yr_pct  return_3yr_pct  return_5yr_pct
# count       40.000000       40.000000       40.000000
# mean        14.376000       14.089000       14.516750
# std          4.883023        4.617253        4.454021
# min          4.260000        5.140000        5.430000
# 25%         11.735000       12.035000       12.340000
# 50%         14.620000       14.205000       14.185000
# 75%         16.392500       15.882500       17.585000
# max         24.930000       23.390000       23.800000

# %%
df["expense_ratio_pct"].describe()
# Out:
# count    40.000000
# mean      1.237000
# std       0.386584
# min       0.550000
# 25%       0.787500
# 50%       1.425000
# 75%       1.540000
# max       1.640000
# Name: expense_ratio_pct, dtype: float64

# %%
df.to_csv("../data/processed/07_scheme_performance_cleaned.csv",index=False)

# %%
df = pd.read_csv("../data/raw/01_fund_master.csv")
print(df)
# Out:
#     amfi_code                fund_house  \
# 0      119551           SBI Mutual Fund
# 1      119552           SBI Mutual Fund
# 2      119598           SBI Mutual Fund
# 3      119599           SBI Mutual Fund
# 4      119120           SBI Mutual Fund
# 5      100016          HDFC Mutual Fund
# 6      125497          HDFC Mutual Fund
# 7      100033          HDFC Mutual Fund
# 8      125498          HDFC Mutual Fund
# 9      100025          HDFC Mutual Fund
# 10     120503       ICICI Prudential MF
# 11     120504       ICICI Prudential MF
# 12     120505       ICICI Prudential MF
# 13     120506       ICICI Prudential MF
# 14     120507       ICICI Prudential MF
# 15     118632           Nippon India MF
# 16     118633           Nippon India MF
# 17     118634           Nippon India MF
# 18     118635           Nippon India MF
# 19     118636           Nippon India MF
# 20     120841         Kotak Mahindra MF
# 21     120842         Kotak Mahindra MF
# ...

# %%
print(df.columns.tolist())
# Out:
# ['amfi_code', 'fund_house', 'scheme_name', 'category', 'sub_category', 'plan', 'launch_date', 'benchmark', 'expense_ratio_pct', 'exit_load_pct', 'min_sip_amount', 'min_lumpsum_amount', 'fund_manager', 'risk_category', 'sebi_category_code']

# %%
for col in df.columns:
    print(col)
# Out:
# amfi_code
# fund_house
# scheme_name
# category
# sub_category
# plan
# launch_date
# benchmark
# expense_ratio_pct
# exit_load_pct
# min_sip_amount
# min_lumpsum_amount
# fund_manager
# risk_category
# sebi_category_code

# %%
df.to_csv("../data/processed/07_scheme_performance_cleaned.csv",index=False)

# %%
import pandas as pd
from pathlib import Path

raw_path = Path("../data/raw")
processed_path = Path("../data/processed")

files = ["01_fund_master.csv","03_aum_by_fund_house.csv","04_monthly_sip_inflows.csv","05_category_inflows.csv","06_industry_folio_count.csv","09_portfolio_holdings.csv","10_benchmark_indices.csv"]

for file in files:
    print(f"\nProcessing {file}")
    df = pd.read_csv(raw_path / file)
    print("Shape:", df.shape)
    print("Missing Values:")
    print(df.isnull().sum().sum())
    cleaned_name = file.replace(".csv", "_cleaned.csv")
    df.to_csv(processed_path / cleaned_name, index=False)

    print(f"Saved: {cleaned_name}")
# Out:
# Processing 01_fund_master.csv
# Shape: (40, 15)
# Missing Values:
# 0
# Saved: 01_fund_master_cleaned.csv
#
# Processing 03_aum_by_fund_house.csv
# Shape: (90, 5)
# Missing Values:
# 0
# Saved: 03_aum_by_fund_house_cleaned.csv
#
# Processing 04_monthly_sip_inflows.csv
# Shape: (48, 6)
# Missing Values:
# 12
# Saved: 04_monthly_sip_inflows_cleaned.csv
#
# Processing 05_category_inflows.csv
# Shape: (144, 3)
# Missing Values:
# 0
# Saved: 05_category_inflows_cleaned.csv
#
# Processing 06_industry_folio_count.csv
# Shape: (21, 6)
# Missing Values:
# 0
# Saved: 06_industry_folio_count_cleaned.csv
#
# Processing 09_portfolio_holdings.csv
# Shape: (322, 8)
# Missing Values:
# 0
# Saved: 09_portfolio_holdings_cleaned.csv
#
# Processing 10_benchmark_indices.csv
# Shape: (8050, 3)
# Missing Values:
# 0
# Saved: 10_benchmark_indices_cleaned.csv

# %%
import pandas as pd
df = pd.read_csv("../data/processed/02_nav_history_claned.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[96], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("../data/processed/02_nav_history_claned.csv")
#       3 df.head()
#
# ...

# %%
print("hello")
# Out:
# hello

# %%
import pandas as pd
df = pd.read_csv("../data/processed/02_nav_history_cleaned.csv")
df.head()
# Out:
#          date index_name  close_value
# 0  2022-01-03    NIFTY50     17492.79
# 1  2022-01-04    NIFTY50     17689.64
# 2  2022-01-05    NIFTY50     17835.05
# 3  2022-01-06    NIFTY50     17878.51
# 4  2022-01-07    NIFTY50     17759.15

# %%
df.tail()
# Out:
#             date   index_name  close_value
# 8045  2026-05-25  CRISIL_GILT      2278.26
# 8046  2026-05-26  CRISIL_GILT      2281.42
# 8047  2026-05-27  CRISIL_GILT      2281.30
# 8048  2026-05-28  CRISIL_GILT      2298.35
# 8049  2026-05-29  CRISIL_GILT      2302.79

# %%
df.columns
# Out:
# Index(['date', 'index_name', 'close_value'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8050 entries, 0 to 8049
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   date         8050 non-null   object
#  1   index_name   8050 non-null   object
#  2   close_value  8050 non-null   float64
# dtypes: float64(1), object(2)
# memory usage: 188.8+ KB

# %%
import pandas as pd
df = pd.read_csv("../data/processed/03_aum_by_fund_house_cleaned.csv")
df.head()
# Out:
#          date           fund_house  aum_lakh_crore  aum_crore  num_schemes
# 0  2022-03-31      SBI Mutual Fund            6.05     605000          186
# 1  2022-03-31  ICICI Prudential MF            4.65     465000          216
# 2  2022-03-31     HDFC Mutual Fund            4.35     435000          195
# 3  2022-03-31      Nippon India MF            2.70     270000          177
# 4  2022-03-31    Kotak Mahindra MF            2.70     270000          168

# %%
df.columns
# Out:
# Index(['date', 'fund_house', 'aum_lakh_crore', 'aum_crore', 'num_schemes'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90 entries, 0 to 89
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   date            90 non-null     object
#  1   fund_house      90 non-null     object
#  2   aum_lakh_crore  90 non-null     float64
#  3   aum_crore       90 non-null     int64
#  4   num_schemes     90 non-null     int64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 3.6+ KB

# %%
df['date'] = pd.to_datetime(df['date'])

# %%
df['year'] = df['date'].dt.year

# %%
df.columns
# Out:
# Index(['date', 'fund_house', 'aum_lakh_crore', 'aum_crore', 'num_schemes',
#        'year'],
#       dtype='object')

# %%
df[['date','year']].head()
# Out:
#         date  year
# 0 2022-03-31  2022
# 1 2022-03-31  2022
# 2 2022-03-31  2022
# 3 2022-03-31  2022
# 4 2022-03-31  2022

# %%
df['year'].unique()
# Out:
# array([2022, 2023, 2024, 2025], dtype=int32)

# %%
df['fund_house'].unique()
# Out:
# array(['SBI Mutual Fund', 'ICICI Prudential MF', 'HDFC Mutual Fund',
#        'Nippon India MF', 'Kotak Mahindra MF', 'Aditya Birla Sun Life MF',
#        'Axis Mutual Fund', 'UTI Mutual Fund', 'Mirae Asset MF',
#        'DSP Mutual Fund'], dtype=object)

# %%
df.groupby('year').size()
# Out:
# year
# 2022    20
# 2023    20
# 2024    30
# 2025    20
# dtype: int64

# %%
df[df['year']==2024]['date'].unique()
# Out:
# <DatetimeArray>
# ['2024-03-31 00:00:00', '2024-09-30 00:00:00', '2024-12-31 00:00:00']
# Length: 3, dtype: datetime64[ns]

# %%
df.groupby('year')['date'].max()
# Out:
# year
# 2022   2022-09-30
# 2023   2023-09-30
# 2024   2024-12-31
# 2025   2025-12-31
# Name: date, dtype: datetime64[ns]

# %%
df['date'].max()
# Out:
# Timestamp('2025-12-31 00:00:00')

# %%
df.groupby('year')['date'].max()
# Out:
# year
# 2022   2022-09-30
# 2023   2023-09-30
# 2024   2024-12-31
# 2025   2025-12-31
# Name: date, dtype: datetime64[ns]

# %%
new_date = df.groupby('year')['date'].max()

# %%
df_date = df.merge(new_date, on = ['year','date'])
df_date.head()
# Out:
#         date           fund_house  aum_lakh_crore  aum_crore  num_schemes  \
# 0 2022-09-30      SBI Mutual Fund            6.30     630000          186
# 1 2022-09-30  ICICI Prudential MF            4.88     488000          216
# 2 2022-09-30     HDFC Mutual Fund            4.45     445000          195
# 3 2022-09-30      Nippon India MF            2.78     278000          177
# 4 2022-09-30    Kotak Mahindra MF            2.72     272000          168
#
#    year
# 0  2022
# 1  2022
# 2  2022
# 3  2022
# 4  2022

# %%
df_date.sort_values('aum_lakh_crore', ascending=False).head(10)
# Out:
#          date           fund_house  aum_lakh_crore  aum_crore  num_schemes  \
# 30 2025-12-31      SBI Mutual Fund           12.50    1250000          186
# 20 2024-12-31      SBI Mutual Fund           11.14    1114000          186
# 31 2025-12-31  ICICI Prudential MF           10.74    1074000          216
# 32 2025-12-31     HDFC Mutual Fund            9.30     930000          195
# 21 2024-12-31  ICICI Prudential MF            8.74     874000          216
# 10 2023-09-30      SBI Mutual Fund            8.45     845000          186
# 22 2024-12-31     HDFC Mutual Fund            7.87     787000          195
# 33 2025-12-31      Nippon India MF            7.00     700000          177
# 0  2022-09-30      SBI Mutual Fund            6.30     630000          186
# 11 2023-09-30  ICICI Prudential MF            5.90     590000          216
#
#     year
# 30  2025
# 20  2024
# 31  2025
# 32  2025
# 21  2024
# 10  2023
# 22  2024
# 33  2025
# 0   2022
# 11  2023

# %% [markdown]
# # Insight 1: SBI Mutual Fund maintained the highest AUM among major fund houses
# The AUM growth chart shows that SBI Mutual Fund consistently held the largest assets under management between 2022 and 2025, highlighting its strong market position and investor trust.
# **Chart Reference:** AUM Growth by Fund House (2022–2025)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.Figure(figsize=(16,4))

# %%
sns.barplot(data=df_date,x='year',y='aum_lakh_crore',hue='fund_house')
# Out:
# <Axes: xlabel='year', ylabel='aum_lakh_crore'>

# %%
#title
plt.title("AUM growth by fund house 2022 - 2025")
#the mail plot
sns.barplot(data=df_date,x='year',y='aum_lakh_crore',hue='fund_house')
plt.xlabel("Year")
plt.ylabel("AUM (Lakh Crore)")
#saparate legend and barplot
plt.legend(title = 'fund_house', bbox_to_anchor = (1.05,1),
loc ='upper left')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
df = pd.read_csv("../data/processed/04_monthly_sip_inflows_cleaned.csv")
df.head()
# Out:
#      month  sip_inflow_crore  active_sip_accounts_crore  \
# 0  2022-01             11517                       4.91
# 1  2022-02             11438                       4.93
# 2  2022-03             12328                       5.09
# 3  2022-04             11863                       5.48
# 4  2022-05             12286                       5.55
#
#    new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 0                   9.10                4.80             NaN
# 1                   8.20                4.85             NaN
# 2                  10.50                5.01             NaN
# 3                   9.52                5.12             NaN
# 4                   8.10                5.15             NaN

# %%
df.columns
# Out:
# Index(['month', 'sip_inflow_crore', 'active_sip_accounts_crore',
#        'new_sip_accounts_lakh', 'sip_aum_lakh_crore', 'yoy_growth_pct'],
#       dtype='object')

# %%
df['month'] = pd.to_datetime(df['month'])
df.head()
# Out:
#        month  sip_inflow_crore  active_sip_accounts_crore  \
# 0 2022-01-01             11517                       4.91
# 1 2022-02-01             11438                       4.93
# 2 2022-03-01             12328                       5.09
# 3 2022-04-01             11863                       5.48
# 4 2022-05-01             12286                       5.55
#
#    new_sip_accounts_lakh  sip_aum_lakh_crore  yoy_growth_pct
# 0                   9.10                4.80             NaN
# 1                   8.20                4.85             NaN
# 2                  10.50                5.01             NaN
# 3                   9.52                5.12             NaN
# 4                   8.10                5.15             NaN

# %%
import plotly.express as px
fig = px.line(df,x='month',y='sip_inflow_crore',title='Monthly SIP inflow trend 2022 - 2025',markers=True)

# %%
fig.add_annotation(x='2025-12-01',y=31002,text='High ₹31,002 Cr',showarrow=True)

# %% [markdown]
# # Insight 2: SIP inflows reached a record high in December 2025
# Monthly SIP contributions showed a strong upward trend between 2022 and 2025. SIP inflows touched an all time high of ₹31,002 crore in December 2025, indicating growing investor participation and confidence in mutual funds.

# %%
df = pd.read_csv("../data/processed/05_category_inflows_cleaned.csv")
df.head()
# Out:
#      month         category  net_inflow_crore
# 0  2024-04        Large Cap            2413.0
# 1  2024-04          Mid Cap            3897.0
# 2  2024-04        Small Cap            3533.0
# 3  2024-04        Flexi Cap            4947.0
# 4  2024-04  Large & Mid Cap            4214.0

# %%
df['month'] = pd.to_datetime(df['month'])
df.head()
# Out:
#        month         category  net_inflow_crore
# 0 2024-04-01        Large Cap            2413.0
# 1 2024-04-01          Mid Cap            3897.0
# 2 2024-04-01        Small Cap            3533.0
# 3 2024-04-01        Flexi Cap            4947.0
# 4 2024-04-01  Large & Mid Cap            4214.0

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 144 entries, 0 to 143
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   month             144 non-null    datetime64[ns]
#  1   category          144 non-null    object
#  2   net_inflow_crore  144 non-null    float64
# dtypes: datetime64[ns](1), float64(1), object(1)
# memory usage: 3.5+ KB
# None

# %%
heatmap = df.pivot_table(index='category', columns='month', values='net_inflow_crore')

# %%
heatmap.head()
# Out:
# month            2024-04-01  2024-05-01  2024-06-01  2024-07-01  2024-08-01  \
# category
# ELSS                  466.0       553.0       472.0       471.0       499.0
# Flexi Cap            4947.0      5529.0      4478.0      4869.0      5562.0
# Gilt                  784.0       836.0       864.0       959.0       952.0
# Hybrid               2955.0      3487.0      3163.0      3291.0      3684.0
# Large & Mid Cap      4214.0      4368.0      4610.0      5023.0      5411.0
#
# month            2024-09-01  2024-10-01  2024-11-01  2024-12-01  2025-01-01  \
# category
# ELSS                  537.0       537.0       571.0       521.0       516.0
# Flexi Cap            5397.0      6004.0      6111.0      4654.0      5603.0
# Gilt                  925.0       898.0       704.0       831.0       744.0
# Hybrid               3015.0      3314.0      3264.0      3538.0      2967.0
# Large & Mid Cap      4528.0      4581.0      5556.0      4878.0      4816.0
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(16,4))
sns.heatmap(heatmap,cmap='YlGnBu',annot=True,fmt='.0f')
plt.title('Category-wise Net Inflow Heatmap')
plt.xlabel('Month')
plt.ylabel('Fund Category')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Category Inflow Analysis
# # Insight 3: Liquid funds received the highest net inflows
# The heatmap shows that Liquid Funds consistently recorded the highest net inflows across most months, significantly exceeding other fund categories. Flexi Cap and Sectoral/Thematic funds also attracted strong investor interest, indicating demand for both liquidity-focused and growth-oriented investment options.
# **Chart Reference:** Category-wise Net Inflow Heatmap

# %%
import pandas as pd
df = pd.read_csv('../data/raw/08_investor_transactions.csv')
df.head()
# Out:
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 1   INV002952       2024-01-01     148567       Redemption      392882
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 4   INV004691       2024-01-01     119094          Lumpsum        8682
#
#          state       city city_tier age_group  gender  annual_income_lakh  \
# 0    Telangana  Hyderabad       T30       56+  Female                77.1
# 1       Punjab   Amritsar       B30     18-25    Male                 7.1
# 2      Haryana  Faridabad       B30     36-45    Male                47.2
# 3  Maharashtra     Mumbai       T30     36-45  Female                54.4
# 4        Delhi      Noida       T30     26-35    Male                14.5
#
#   payment_mode kyc_status
# 0          UPI   Verified
# 1       Cheque   Verified
# ...

# %%
df.columns
# Out:
# Index(['investor_id', 'transaction_date', 'amfi_code', 'transaction_type',
#        'amount_inr', 'state', 'city', 'city_tier', 'age_group', 'gender',
#        'annual_income_lakh', 'payment_mode', 'kyc_status'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt
counts = df['age_group'].value_counts()
plt.figure(figsize=(8,8))
plt.pie(counts, labels=counts.index, autopct='%1.1f%%')
plt.title('Investor Distribution by Age Group')
plt.show()

# %% [markdown]
# # Investor Age Group Analysis
# # Insight 4: Investors aged 26–35 form the largest investor segment
# The age distribution chart shows that the 26–35 age group accounts for 41.1% of all investors, making it the dominant investor segment. This suggests that young working professionals are the primary contributors to mutual fund investments.
# **Chart Reference:** Investor Distribution by Age Group

# %%
print(df['transaction_type'].value_counts())
# Out:
# transaction_type
# SIP           19716
# Lumpsum        8095
# Redemption     4967
# Name: count, dtype: int64

# %%
sip = df[df['transaction_type'] == 'SIP']

# %%
print(sip.shape)
print(sip.head())
# Out:
# (19716, 13)
#   investor_id transaction_date  amfi_code transaction_type  amount_inr  \
# 0   INV003054       2024-01-01     119092              SIP        1834
# 2   INV003420       2024-01-01     118636              SIP         912
# 3   INV003436       2024-01-01     118634              SIP        1102
# 5   INV001497       2024-01-01     101208              SIP        3295
# 6   INV000786       2024-01-01     101208              SIP       15047
#
#             state       city city_tier age_group  gender  annual_income_lakh  \
# 0       Telangana  Hyderabad       T30       56+  Female                77.1
# 2         Haryana  Faridabad       B30     36-45    Male                47.2
# 3     Maharashtra     Mumbai       T30     36-45  Female                54.4
# 5     Maharashtra     Mumbai       T30     36-45    Male                56.8
# 6  Madhya Pradesh     Bhopal       B30     26-35    Male                17.9
#
#   payment_mode kyc_status
# 0          UPI   Verified
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
sns.boxplot(data=sip, x='age_group', y='amount_inr')
plt.title('SIP Amount Distribution by Age Group')
plt.xlabel('Age Group')
plt.ylabel('SIP Amount in INR')
plt.show()

# %% [markdown]
# # SIP Investment Behaviour by Age Group
# # Insight 5: SIP investment amounts are broadly similar across age groups
# The box plot indicates that median SIP contributions are relatively consistent across all age groups. However, several high-value outliers are observed, particularly among investors aged 46–55 and 56+, suggesting that a subset of older investors contributes significantly larger SIP amounts.
# **Chart Reference:** SIP Amount Distribution by Age Group

# %%
gender_count = df['gender'].value_counts()
plt.figure(figsize=(6,6))
plt.pie(gender_count, labels=gender_count.index, autopct='%1.1f%%')
plt.title('Gender Distribution of Investors')
plt.show()

# %% [markdown]
# # Gender Distribution Analysis
# # Insight 6: Male investors dominate the investor base
# The gender distribution chart shows that male investors account for 66.5% of all investors, while female investors represent 33.5%. This suggests that although female participation in mutual fund investing is significant, male investors continue to dominate the investor base.
# **Chart Reference:** Gender Distribution of Investors

# %%
state = ( df[df['transaction_type'] == 'SIP'].groupby('state')['amount_inr'].sum().sort_values(ascending=False))

# %%
state.head()
# Out:
# state
# Madhya Pradesh    20682243
# Punjab            20140064
# Telangana         18620216
# Tamil Nadu        18404368
# Gujarat           18378904
# Name: amount_inr, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
state.plot( kind='barh')
plt.title('Total SIP Amount by State')
plt.xlabel('SIP Amount in INR')
plt.ylabel('State')
plt.tight_layout()
plt.show()

# %%
count = df['city_tier'].value_counts()
print(count)
# Out:
# city_tier
# T30    21719
# B30    11059
# Name: count, dtype: int64

# %%
plt.figure(figsize=(6,6))
plt.pie(count,labels=counts.index,autopct='%1.1f%%')
plt.title('T30 vs B30 Investor Distribution')
plt.show()

# %% [markdown]
# # City Tier Analysis
# # Insight 8: T30 cities account for the majority of investors
# The city-tier distribution shows that 66.3% of investors belong to T30 cities, while 33.7% come from B30 cities. This indicates that mutual fund participation remains concentrated in major urban centers, although investor adoption in smaller cities is steadily growing.
# **Chart Reference:** T30 vs B30 Investor Distribution

# %%
sip = df[df['transaction_type'] == 'SIP']

# %%
state = (sip.groupby('state')['amount_inr'].sum().sort_values(ascending=True))

# %%
print(state_sip.head())
print(state_sip.tail())
# Out:
# state
# Madhya Pradesh    20682243
# Punjab            20140064
# Telangana         18620216
# Tamil Nadu        18404368
# Gujarat           18378904
# Name: amount_inr, dtype: int64
# state
# Uttar Pradesh    17534858
# West Bengal      17495769
# Delhi            17113608
# Rajasthan        16544233
# Maharashtra      16445629
# Name: amount_inr, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
state_sip.plot(kind='barh')
plt.title('Total SIP Amount by State')
plt.xlabel('Total SIP Amount in INR')
plt.ylabel('State')
plt.tight_layout()
plt.show()

# %%
import pandas as pd
df = pd.read_csv('../data/raw/06_industry_folio_count.csv')
df.head()
# Out:
#      month  total_folios_crore  equity_folios_crore  debt_folios_crore  \
# 0  2022-01               13.26                 9.28               1.86
# 1  2022-04               13.91                 9.74               1.95
# 2  2022-07               13.85                 9.69               1.94
# 3  2022-10               14.12                 9.88               1.98
# 4  2023-01               14.81                10.37               2.07
#
#    hybrid_folios_crore  others_folios_crore
# 0                 0.80                 1.33
# 1                 0.83                 1.39
# 2                 0.83                 1.38
# 3                 0.85                 1.41
# 4                 0.89                 1.48

# %%
df.columns
# Out:
# Index(['month', 'total_folios_crore', 'equity_folios_crore',
#        'debt_folios_crore', 'hybrid_folios_crore', 'others_folios_crore'],
#       dtype='object')

# %%
#converting date
df['month'] = pd.to_datetime(df['month'])
df.head()
# Out:
#        month  total_folios_crore  equity_folios_crore  debt_folios_crore  \
# 0 2022-01-01               13.26                 9.28               1.86
# 1 2022-04-01               13.91                 9.74               1.95
# 2 2022-07-01               13.85                 9.69               1.94
# 3 2022-10-01               14.12                 9.88               1.98
# 4 2023-01-01               14.81                10.37               2.07
#
#    hybrid_folios_crore  others_folios_crore
# 0                 0.80                 1.33
# 1                 0.83                 1.39
# 2                 0.83                 1.38
# 3                 0.85                 1.41
# 4                 0.89                 1.48

# %%
import plotly.express as px
fig = px.line(df,x='month', y='total_folios_crore', title='Industry Folio Count Growth (2022-2025)',
               markers=True)
fig.add_annotation( x=df.iloc[0]['month'], y=df.iloc[0]['total_folios_crore'], text='13.26 Cr', showarrow=True)

fig.add_annotation( x=df.iloc[-1]['month'], y=df.iloc[-1]['total_folios_crore'], text='26.12 Cr', showarrow=True)
fig.show()

# %% [markdown]
# # Folio Count Growth Analysis
# # Insight 9: Mutual fund folio count nearly doubled between 2022 and 2025
# The industry folio count increased from 13.26 crore in January 2022 to 26.12 crore in December 2025. This substantial growth reflects rising retail investor participation and increasing adoption of mutual fund investments across India.
# **Chart Reference:** Industry Folio Count Growth (2022–2025)

# %%
import pandas as pd
df = pd.read_csv("../data/raw/02_nav_history.csv")
df.head()
# Out:
#    amfi_code        date      nav
# 0     119551  2022-01-03  54.3856
# 1     119551  2022-01-04  54.3474
# 2     119551  2022-01-05  54.6869
# 3     119551  2022-01-06  55.4550
# 4     119551  2022-01-07  55.3692

# %%
df['date'] = pd.to_datetime(df['date'])
df.head()
# Out:
#    amfi_code       date      nav
# 0     119551 2022-01-03  54.3856
# 1     119551 2022-01-04  54.3474
# 2     119551 2022-01-05  54.6869
# 3     119551 2022-01-06  55.4550
# 4     119551 2022-01-07  55.3692

# %%
funds = df['amfi_code'][:11]
nav = df[df['amfi_code'].isin(funds)]

# %%
print(funds)
# Out:
# 0    119551
# 1    119551
# 2    119551
# 3    119551
# 4    119551
# 5    119551
# 6    119551
# 7    119551
# 8    119551
# 9    119551
# Name: amfi_code, dtype: int64

# %%
pivot_nav = df.pivot(index='date', columns='amfi_code', values='nav')
df.head()
# Out:
#    amfi_code       date      nav
# 0     119551 2022-01-03  54.3856
# 1     119551 2022-01-04  54.3474
# 2     119551 2022-01-05  54.6869
# 3     119551 2022-01-06  55.4550
# 4     119551 2022-01-07  55.3692

# %%
df.head()
# Out:
#    amfi_code       date      nav
# 0     119551 2022-01-03  54.3856
# 1     119551 2022-01-04  54.3474
# 2     119551 2022-01-05  54.6869
# 3     119551 2022-01-06  55.4550
# 4     119551 2022-01-07  55.3692

# %%
returns = pivot_nav.pct_change().dropna()

# %%
corr_matrix = returns.corr()

# %%
corr_matrix.head()
# Out:
# amfi_code    100016    100025    100033    101206    101207    101208  \
# amfi_code
# 100016     1.000000  0.045567 -0.000006  0.027747  0.016053 -0.033773
# 100025     0.045567  1.000000  0.002150  0.023769 -0.006710  0.018455
# 100033    -0.000006  0.002150  1.000000 -0.018079  0.000351  0.007864
# 101206     0.027747  0.023769 -0.018079  1.000000  0.010202 -0.027230
# 101207     0.016053 -0.006710  0.000351  0.010202  1.000000 -0.007530
#
# amfi_code    102885    102886    102887    118632  ...    120843    120844  \
# amfi_code                                          ...
# 100016    -0.093533 -0.005867 -0.023316 -0.026781  ...  0.023033 -0.006097
# 100025    -0.001038  0.013754 -0.005648 -0.014166  ... -0.003257  0.022290
# 100033    -0.034228 -0.018166 -0.036647 -0.013318  ...  0.023025  0.010619
# 101206     0.001570  0.007229 -0.006490 -0.005432  ... -0.008136  0.009300
# 101207    -0.005929  0.004860  0.002304  0.043384  ...  0.058576 -0.075322
#
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10,8))
sns.heatmap( corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('NAV Return Correlation Matrix (10 Selected Funds)')
plt.show()

# %%
funds = df['amfi_code'].unique()[:10]
print(funds)
print(len(funds))
# Out:
# [119551 119552 119598 119599 119120 100016 125497 100033 125498 100025]
# 10

# %%
funds = df['amfi_code'].unique()[:10]
nav_10 = df[df['amfi_code'].isin(funds)]
pivot_nav = nav_10.pivot( index='date', columns='amfi_code',  values='nav')
returns = pivot_nav.pct_change().dropna()
corr_matrix = returns.corr()
print(corr_matrix.shape)
# Out:
# (10, 10)

# %%
plt.figure(figsize=(8,6))
sns.heatmap( corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('NAV Return Correlation Matrix (10 Selected Funds)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # NAV Return Correlation Analysis
# # Insight 10: Selected mutual funds exhibit weak return correlations
# The NAV return correlation matrix shows that most pairwise correlations among the selected funds are close to zero, indicating weak relationships between daily returns. This suggests that the selected funds provide diversification benefits, as their short-term performance movements are largely independent of one another.
# **Chart Reference:** NAV Return Correlation Matrix (10 Selected Funds)

# %%
import pandas as pd
df= pd.read_csv('../data/processed/09_portfolio_holdings_cleaned.csv')
df.head()
# Out:
#    amfi_code stock_symbol                stock_name       sector  weight_pct  \
# 0     119551    POWERGRID    Power Grid Corporation    Utilities       13.85
# 1     119551     HDFCBANK             HDFC Bank Ltd      Banking       11.19
# 2     119551       GRASIM     Grasim Industries Ltd  Diversified        9.90
# 3     119551      DRREDDY  Dr. Reddy's Laboratories       Pharma        4.76
# 4     119551   ASIANPAINT          Asian Paints Ltd       Paints       10.25
#
#    market_value_cr  current_price_inr portfolio_date
# 0           737.09            6011.08     2025-12-31
# 1            88.97            1074.65     2025-12-31
# 2           208.45            5964.59     2025-12-31
# 3           161.32            3748.82     2025-12-31
# 4           725.90            1321.45     2025-12-31

# %%
print(df.columns)
df.head()
# Out:
# Index(['amfi_code', 'stock_symbol', 'stock_name', 'sector', 'weight_pct',
#        'market_value_cr', 'current_price_inr', 'portfolio_date'],
#       dtype='object')
#    amfi_code stock_symbol                stock_name       sector  weight_pct  \
# 0     119551    POWERGRID    Power Grid Corporation    Utilities       13.85
# 1     119551     HDFCBANK             HDFC Bank Ltd      Banking       11.19
# 2     119551       GRASIM     Grasim Industries Ltd  Diversified        9.90
# 3     119551      DRREDDY  Dr. Reddy's Laboratories       Pharma        4.76
# 4     119551   ASIANPAINT          Asian Paints Ltd       Paints       10.25
#
#    market_value_cr  current_price_inr portfolio_date
# 0           737.09            6011.08     2025-12-31
# 1            88.97            1074.65     2025-12-31
# 2           208.45            5964.59     2025-12-31
# 3           161.32            3748.82     2025-12-31
# 4           725.90            1321.45     2025-12-31

# %%
sector_allocation = (df.groupby('sector')['weight_pct'].sum().sort_values(ascending=False))
sector_allocation
# Out:
# sector
# Banking           652.26
# IT                455.47
# Pharma            407.45
# Automobile        323.65
# Utilities         265.54
# FMCG              229.11
# Infrastructure    192.16
# Diversified       169.23
# Telecom           145.62
# Consumer Goods    127.61
# NBFC              119.09
# Energy            117.91
# Cement            105.03
# Paints             89.86
# Name: weight_pct, dtype: float64

# %%
sector_allocation = ( df.groupby('sector')['weight_pct'].sum().sort_values(ascending=False))
sector_allocation
# Out:
# sector
# Banking           652.26
# IT                455.47
# Pharma            407.45
# Automobile        323.65
# Utilities         265.54
# FMCG              229.11
# Infrastructure    192.16
# Diversified       169.23
# Telecom           145.62
# Consumer Goods    127.61
# NBFC              119.09
# Energy            117.91
# Cement            105.03
# Paints             89.86
# Name: weight_pct, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,8))
plt.pie( sector_allocation, labels=sector_allocation.index, autopct='%1.1f%%')
# Created donut hole
centre_circle = plt.Circle((0,0), 0.70, fc='white')
fig = plt.gcf()
fig.gca().add_artist(centre_circle)
plt.title('Sector Allocation Across Equity Funds')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Sector Allocation Analysis
# # Insight 11: Banking, IT, and Pharma dominate equity fund allocations
# The sector allocation donut chart shows that Banking (19.2%), IT (13.4%), and Pharma (12.0%) together account for a significant share of total portfolio holdings. This suggests that fund managers favor sectors with strong market capitalization, earnings potential, and long-term growth prospects while maintaining diversification across other industries.
# **Chart Reference:** Sector Allocation Across Equity Funds

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv('../data/processed/04_monthly_sip_inflows_cleaned.csv')

df['month'] = pd.to_datetime(df['month'])

fig = px.line(df,x='month',y='active_sip_accounts_crore',title='Active SIP Accounts Growth (2022-2025)',markers=True)
fig.show()

# %% [markdown]
# # Insight 12: Active SIP accounts increased steadily between 2022 and 2025
# The number of active SIP accounts grew consistently throughout the period, indicating increasing participation of retail investors in mutual funds.
# **Chart Reference:** Active SIP Accounts Growth (2022-2025)

# %%
import pandas as pd
import plotly.express as px
df = pd.read_csv('../data/processed/04_monthly_sip_inflows_cleaned.csv')
df['month'] = pd.to_datetime(df['month'])
fig = px.line(df,x='month',y='new_sip_accounts_lakh',title='New SIP Accounts Growth (2022-2025)',markers=True)
fig.show()

# %% [markdown]
# # Insight 13: New SIP account registrations remained strong
# New SIP account creation remained consistently high during the period, reflecting growing awareness and adoption of SIP investments.
# **Chart Reference:** New SIP Accounts Growth (2022-2025)

# %%
import pandas as pd
import plotly.express as px
df = pd.read_csv('../data/processed/04_monthly_sip_inflows_cleaned.csv')
df['month'] = pd.to_datetime(df['month'])
fig = px.line( df,x='month',y='sip_aum_lakh_crore',title='SIP AUM Growth 2022-2025',markers=True)
fig.show()

# %% [markdown]
# # Insight 14: SIP Assets Under Management grew significantly
# SIP AUM increased steadily from 2022 to 2025, demonstrating stronger investor commitment to long-term wealth creation through systematic investments.
# **Chart Reference:** SIP AUM Growth (2022-2025)

# %%
df = pd.read_csv('../data/processed/04_monthly_sip_inflows_cleaned.csv')
print(df.columns)
# Out:
# Index(['month', 'sip_inflow_crore', 'active_sip_accounts_crore',
#        'new_sip_accounts_lakh', 'sip_aum_lakh_crore', 'yoy_growth_pct'],
#       dtype='object')

# %%
import pandas as pd
import plotly.express as px

df = pd.read_csv('../data/processed/02_nav_history_cleaned.csv')
df['date'] = pd.to_datetime(df['date'])
fig = px.line( df,x='date',y='nav',color='amfi_code',title='Daily NAV Trends Across 40 Mutual Fund Schemes (2022–2026)')
fig.add_vrect(x0='2023-01-01', x1='2023-12-31', annotation_text='2023 Bull Run', fillcolor='green', opacity=0.15, line_width=0)
fig.add_vrect( x0='2024-01-01', x1='2024-06-30', annotation_text='2024 Market Correction', fillcolor='red', opacity=0.15, line_width=0)
fig.show()

# %% [markdown]
# # NAV Trend Analysis
# # Insight 15: Most schemes showed strong NAV growth during the 2023 bull market
# The NAV trend chart indicates that a majority of mutual fund schemes experienced steady appreciation during 2023, while some temporary corrections were visible during 2024 before growth resumed.
# **Chart Reference:** Daily NAV Trends Across Mutual Fund Schemes (2022–2026)
